# %% [markdown]
# # Web Scraping Practice Pipeline

# %% [markdown]
# ### Step 1: Import Required Libraries

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2: Access Website

# %%
page_num = 3
make = 'acura'
url = f'https://www.truecar.com/used-cars-for-sale/listings/'

response = requests.get(url, timeout=5)

response.status_code
# Out:
# 200

# %% [markdown]
# ### Step 3: Access Used Car Listing Objects

# %%
soup = BeautifulSoup(response.content, 'html.parser')

results = soup.find_all('div', {'class' : 'linkable card card-shadow vehicle-card'})

len(results)
# Out:
# 33

# %% [markdown]
# ### Step 4: Get Individual Parameters and Output to DataFrame

# %%
vin = []
header = []
trim = []
price = []
mileage = []
colors = []
condition = []
location = []

for result in results:
    
    # vin
    try:
        vin.append(result.find('div', {'class':'vehicle-card-vin-carousel mt-1 text-xs'}).get_text())
    except:
        vin.append('n/a')
    # header
    try:
        header.append(result.find('div', {'class':'vehicle-card-header'}).get_text())
    except:
        header.append('n/a')
    
    # trim
    try:
        trim.append(result.find('div', {'data-test':'vehicleCardTrim'}).get_text())
    except:
        trim.append('n/a')
    # price
    try:
        price.append(result.find('div', {'class':'vehicle-card-bottom-pricing-secondary pl-3 lg:pl-2 vehicle-card-bottom-max-50'}).get_text())
    except:
        price.append('n/a')
    
    # mileage
    try:
        mileage.append(result.find('div', {'data-test':'vehicleMileage'}).get_text())
    except:
        mileage.append('n/a')
    
    # colors
    try:
        colors.append(result.find('div', {'data-test':'vehicleCardColors'}).get_text())
    except:
        colors.append('n/a')
    
    # condition
    try:
        condition.append(result.find('div', {'data-test':'vehicleCardCondition'}).get_text())
    except:
        condition.append('n/a')
    
    # location
    try:
        location.append(result.find('div', {'data-test': 'vehicleCardLocation'}).get_text())
    except:
        location.append('n/a')
        

car_listings = pd.DataFrame({'vin': vin, 'header': header, 'trim': trim, 'price': price, 'mileage': mileage, 'colors': colors, 'condition': condition, 'location': location})

# %% [markdown]
# ### Step 5: Preview Raw Tabular Data

# %%
car_listings.head(5)
# Out:
#                     vin                                header
# 0  VIN1FTBR1C83LKA62166  Sponsored2020 Ford Transit Cargo Van  \
# 1  VIN1GNSKDKD3NR208863      Sponsored2022 Chevrolet Suburban
# 2  VIN1G1FZ6S02N4108127      Sponsored2022 Chevrolet Bolt EUV
# 3  VIN1FTEW1EB4MFA62542                       2021 Ford F-150
# 4  VIN1FTFW1E89MFA71147                       2021 Ford F-150
#
#                                    trim    price       mileage
# 0  T-250 148" Medium Roof 9070 GVWR RWD  $41,577  24,465 miles  \
# 1                               Z71 4WD  $65,998  27,058 miles
# 2                               Premier  $33,998   2,370 miles
# 3            XLT SuperCrew 5.5' Box 4WD  $38,499  15,745 miles
# 4            XLT SuperCrew 5.5' Box 4WD  $35,990  45,732 miles
#
#                            colors
# 0   White exterior, Gray interior  \
# 1   Gray exterior, Black interior
# 2   Black exterior, Gray interior
# 3  White exterior, Black interior
# 4   Blue exterior, Black interior
#
#                                       condition             location
# 0             1 accident, 1 Owner, Personal use       Lewisville, TX
# 1  No accidents reported, 1 Owner, Personal use          Tomball, TX
# 2  No accidents reported, 1 Owner, Personal use           Waukee, IA
# 3  No accidents reported, 1 Owner, Personal use        Blackfoot, ID
# 4             1 accident, 1 Owner, Personal use  North Lake City, UT

# %% [markdown]
# ### Step 6: Extract Model Year from Listing Header

# %%
car_listings['year'] = np.where(car_listings['header'].str.startswith('Spon'), car_listings['header'].str[9:13], car_listings['header'].str[:5])
car_listings.head(5)
# Out:
#                     vin                                header
# 0  VIN1FTBR1C83LKA62166  Sponsored2020 Ford Transit Cargo Van  \
# 1  VIN1GNSKDKD3NR208863      Sponsored2022 Chevrolet Suburban
# 2  VIN1G1FZ6S02N4108127      Sponsored2022 Chevrolet Bolt EUV
# 3  VIN1FTEW1EB4MFA62542                       2021 Ford F-150
# 4  VIN1FTFW1E89MFA71147                       2021 Ford F-150
#
#                                    trim    price       mileage
# 0  T-250 148" Medium Roof 9070 GVWR RWD  $41,577  24,465 miles  \
# 1                               Z71 4WD  $65,998  27,058 miles
# 2                               Premier  $33,998   2,370 miles
# 3            XLT SuperCrew 5.5' Box 4WD  $38,499  15,745 miles
# 4            XLT SuperCrew 5.5' Box 4WD  $35,990  45,732 miles
#
#                            colors
# 0   White exterior, Gray interior  \
# 1   Gray exterior, Black interior
# 2   Black exterior, Gray interior
# 3  White exterior, Black interior
# 4   Blue exterior, Black interior
#
#                                       condition             location   year
# 0             1 accident, 1 Owner, Personal use       Lewisville, TX   2020
# 1  No accidents reported, 1 Owner, Personal use          Tomball, TX   2022
# 2  No accidents reported, 1 Owner, Personal use           Waukee, IA   2022
# 3  No accidents reported, 1 Owner, Personal use        Blackfoot, ID  2021
# 4             1 accident, 1 Owner, Personal use  North Lake City, UT  2021

# %% [markdown]
# ### Step 7: Extract Make and Model from Listing Header

# %%
try:
    new_cols = car_listings['header'].str.split(" ", n=5, expand=True)
    car_listings['make'] = new_cols[1]
    car_listings['model'] = new_cols[2]
    car_listings['model2'] = new_cols[3]
    car_listings['model3'] = new_cols[4]
except:
    new_cols = car_listings['header'].str.split(" ", n=4, expand=True)
    car_listings['make'] = new_cols[1]
    car_listings['model'] = new_cols[2]
    car_listings['model2'] = new_cols[3]
    
car_listings.head(5)
# Out:
#                     vin                                header
# 0  VIN1FTBR1C83LKA62166  Sponsored2020 Ford Transit Cargo Van  \
# 1  VIN1GNSKDKD3NR208863      Sponsored2022 Chevrolet Suburban
# 2  VIN1G1FZ6S02N4108127      Sponsored2022 Chevrolet Bolt EUV
# 3  VIN1FTEW1EB4MFA62542                       2021 Ford F-150
# 4  VIN1FTFW1E89MFA71147                       2021 Ford F-150
#
#                                    trim    price       mileage
# 0  T-250 148" Medium Roof 9070 GVWR RWD  $41,577  24,465 miles  \
# 1                               Z71 4WD  $65,998  27,058 miles
# 2                               Premier  $33,998   2,370 miles
# 3            XLT SuperCrew 5.5' Box 4WD  $38,499  15,745 miles
# 4            XLT SuperCrew 5.5' Box 4WD  $35,990  45,732 miles
#
#                            colors
# 0   White exterior, Gray interior  \
# 1   Gray exterior, Black interior
# 2   Black exterior, Gray interior
# 3  White exterior, Black interior
# 4   Blue exterior, Black interior
#
#                                       condition             location   year
# 0             1 accident, 1 Owner, Personal use       Lewisville, TX   2020  \
# 1  No accidents reported, 1 Owner, Personal use          Tomball, TX   2022
# 2  No accidents reported, 1 Owner, Personal use           Waukee, IA   2022
# 3  No accidents reported, 1 Owner, Personal use        Blackfoot, ID  2021
# 4             1 accident, 1 Owner, Personal use  North Lake City, UT  2021
#
#         make     model model2 model3
# 0       Ford   Transit  Cargo    Van
# 1  Chevrolet  Suburban   None   None
# 2  Chevrolet      Bolt    EUV   None
# 3       Ford     F-150   None   None
# 4       Ford     F-150   None   None

# %% [markdown]
# ### Step 8: Drop "header" Column and Reorder Columns

# %%
car_listings = car_listings.drop(columns=['header'])
try:
    car_listings = car_listings[['vin', 'year', 'make', 'model', 'model2', 'model3', 'trim', 'price', 'mileage', 'colors', 'condition', 'location']]
except:
    car_listings = car_listings[['vin', 'year', 'make', 'model', 'model2', 'trim', 'price', 'mileage', 'colors', 'condition', 'location']]
car_listings.head(5)
# Out:
#                     vin   year       make     model model2 model3
# 0  VIN1FTBR1C83LKA62166   2020       Ford   Transit  Cargo    Van  \
# 1  VIN1GNSKDKD3NR208863   2022  Chevrolet  Suburban   None   None
# 2  VIN1G1FZ6S02N4108127   2022  Chevrolet      Bolt    EUV   None
# 3  VIN1FTEW1EB4MFA62542  2021        Ford     F-150   None   None
# 4  VIN1FTFW1E89MFA71147  2021        Ford     F-150   None   None
#
#                                    trim    price       mileage
# 0  T-250 148" Medium Roof 9070 GVWR RWD  $41,577  24,465 miles  \
# 1                               Z71 4WD  $65,998  27,058 miles
# 2                               Premier  $33,998   2,370 miles
# 3            XLT SuperCrew 5.5' Box 4WD  $38,499  15,745 miles
# 4            XLT SuperCrew 5.5' Box 4WD  $35,990  45,732 miles
#
#                            colors
# 0   White exterior, Gray interior  \
# 1   Gray exterior, Black interior
# 2   Black exterior, Gray interior
# 3  White exterior, Black interior
# 4   Blue exterior, Black interior
#
#                                       condition             location
# 0             1 accident, 1 Owner, Personal use       Lewisville, TX
# 1  No accidents reported, 1 Owner, Personal use          Tomball, TX
# 2  No accidents reported, 1 Owner, Personal use           Waukee, IA
# 3  No accidents reported, 1 Owner, Personal use        Blackfoot, ID
# 4             1 accident, 1 Owner, Personal use  North Lake City, UT

# %% [markdown]
# ### Step 9: Remove "$" and "," from "price" Column and Convert to Int

# %%
car_listings['price'] = car_listings['price'].str.replace('$', '')
car_listings['price'] = car_listings['price'].str.replace(',', '')
car_listings['price'] = car_listings['price'].astype(int)
car_listings.head(5)
# Out:
#                     vin   year       make     model model2 model3
# 0  VIN1FTBR1C83LKA62166   2020       Ford   Transit  Cargo    Van  \
# 1  VIN1GNSKDKD3NR208863   2022  Chevrolet  Suburban   None   None
# 2  VIN1G1FZ6S02N4108127   2022  Chevrolet      Bolt    EUV   None
# 3  VIN1FTEW1EB4MFA62542  2021        Ford     F-150   None   None
# 4  VIN1FTFW1E89MFA71147  2021        Ford     F-150   None   None
#
#                                    trim  price       mileage
# 0  T-250 148" Medium Roof 9070 GVWR RWD  41577  24,465 miles  \
# 1                               Z71 4WD  65998  27,058 miles
# 2                               Premier  33998   2,370 miles
# 3            XLT SuperCrew 5.5' Box 4WD  38499  15,745 miles
# 4            XLT SuperCrew 5.5' Box 4WD  35990  45,732 miles
#
#                            colors
# 0   White exterior, Gray interior  \
# 1   Gray exterior, Black interior
# 2   Black exterior, Gray interior
# 3  White exterior, Black interior
# 4   Blue exterior, Black interior
#
#                                       condition             location
# 0             1 accident, 1 Owner, Personal use       Lewisville, TX
# 1  No accidents reported, 1 Owner, Personal use          Tomball, TX
# 2  No accidents reported, 1 Owner, Personal use           Waukee, IA
# 3  No accidents reported, 1 Owner, Personal use        Blackfoot, ID
# 4             1 accident, 1 Owner, Personal use  North Lake City, UT

# %% [markdown]
# ### Step 9: Remove "miles" and "," from "mileage" Column and Convert to Int

# %%
car_listings['mileage'] = car_listings['mileage'].str.replace('miles', '')
car_listings['mileage'] = car_listings['mileage'].str.replace(',', '')
car_listings['mileage'] = car_listings['mileage'].astype(int)
car_listings.head(5)
# Out:
#                     vin   year       make     model model2 model3
# 0  VIN1FTBR1C83LKA62166   2020       Ford   Transit  Cargo    Van  \
# 1  VIN1GNSKDKD3NR208863   2022  Chevrolet  Suburban   None   None
# 2  VIN1G1FZ6S02N4108127   2022  Chevrolet      Bolt    EUV   None
# 3  VIN1FTEW1EB4MFA62542  2021        Ford     F-150   None   None
# 4  VIN1FTFW1E89MFA71147  2021        Ford     F-150   None   None
#
#                                    trim  price  mileage
# 0  T-250 148" Medium Roof 9070 GVWR RWD  41577    24465  \
# 1                               Z71 4WD  65998    27058
# 2                               Premier  33998     2370
# 3            XLT SuperCrew 5.5' Box 4WD  38499    15745
# 4            XLT SuperCrew 5.5' Box 4WD  35990    45732
#
#                            colors
# 0   White exterior, Gray interior  \
# 1   Gray exterior, Black interior
# 2   Black exterior, Gray interior
# 3  White exterior, Black interior
# 4   Blue exterior, Black interior
#
#                                       condition             location
# 0             1 accident, 1 Owner, Personal use       Lewisville, TX
# 1  No accidents reported, 1 Owner, Personal use          Tomball, TX
# 2  No accidents reported, 1 Owner, Personal use           Waukee, IA
# 3  No accidents reported, 1 Owner, Personal use        Blackfoot, ID
# 4             1 accident, 1 Owner, Personal use  North Lake City, UT

# %% [markdown]
# ### Step 10: Split "colors" Column into "exterior_color" and "interior_color" Columns

# %%
new_cols = car_listings['colors'].str.split(",", n=2, expand=True)
car_listings['exterior_color'] = new_cols[0]
car_listings['interior_color'] = new_cols[1]
car_listings.head(5)
# Out:
#                     vin   year       make     model model2 model3
# 0  VIN1FTBR1C83LKA62166   2020       Ford   Transit  Cargo    Van  \
# 1  VIN1GNSKDKD3NR208863   2022  Chevrolet  Suburban   None   None
# 2  VIN1G1FZ6S02N4108127   2022  Chevrolet      Bolt    EUV   None
# 3  VIN1FTEW1EB4MFA62542  2021        Ford     F-150   None   None
# 4  VIN1FTFW1E89MFA71147  2021        Ford     F-150   None   None
#
#                                    trim  price  mileage
# 0  T-250 148" Medium Roof 9070 GVWR RWD  41577    24465  \
# 1                               Z71 4WD  65998    27058
# 2                               Premier  33998     2370
# 3            XLT SuperCrew 5.5' Box 4WD  38499    15745
# 4            XLT SuperCrew 5.5' Box 4WD  35990    45732
#
#                            colors
# 0   White exterior, Gray interior  \
# 1   Gray exterior, Black interior
# 2   Black exterior, Gray interior
# 3  White exterior, Black interior
# 4   Blue exterior, Black interior
#
#                                       condition             location
# 0             1 accident, 1 Owner, Personal use       Lewisville, TX  \
# 1  No accidents reported, 1 Owner, Personal use          Tomball, TX
# 2  No accidents reported, 1 Owner, Personal use           Waukee, IA
# 3  No accidents reported, 1 Owner, Personal use        Blackfoot, ID
# 4             1 accident, 1 Owner, Personal use  North Lake City, UT
#
#    exterior_color   interior_color
# 0  White exterior    Gray interior
# 1   Gray exterior   Black interior
# 2  Black exterior    Gray interior
# 3  White exterior   Black interior
# 4   Blue exterior   Black interior

# %% [markdown]
# ### Step 11: Remove "exterior" and "interior" From "exterior_color" and "interior_color" Columns, Respectively

# %%
car_listings['exterior_color'] = car_listings['exterior_color'].str.replace('exterior', '')
car_listings['interior_color'] = car_listings['interior_color'].str.replace('interior', '')
car_listings.head(5)
# Out:
#                     vin   year       make     model model2 model3
# 0  VIN1FTBR1C83LKA62166   2020       Ford   Transit  Cargo    Van  \
# 1  VIN1GNSKDKD3NR208863   2022  Chevrolet  Suburban   None   None
# 2  VIN1G1FZ6S02N4108127   2022  Chevrolet      Bolt    EUV   None
# 3  VIN1FTEW1EB4MFA62542  2021        Ford     F-150   None   None
# 4  VIN1FTFW1E89MFA71147  2021        Ford     F-150   None   None
#
#                                    trim  price  mileage
# 0  T-250 148" Medium Roof 9070 GVWR RWD  41577    24465  \
# 1                               Z71 4WD  65998    27058
# 2                               Premier  33998     2370
# 3            XLT SuperCrew 5.5' Box 4WD  38499    15745
# 4            XLT SuperCrew 5.5' Box 4WD  35990    45732
#
#                            colors
# 0   White exterior, Gray interior  \
# 1   Gray exterior, Black interior
# 2   Black exterior, Gray interior
# 3  White exterior, Black interior
# 4   Blue exterior, Black interior
#
#                                       condition             location
# 0             1 accident, 1 Owner, Personal use       Lewisville, TX  \
# 1  No accidents reported, 1 Owner, Personal use          Tomball, TX
# 2  No accidents reported, 1 Owner, Personal use           Waukee, IA
# 3  No accidents reported, 1 Owner, Personal use        Blackfoot, ID
# 4             1 accident, 1 Owner, Personal use  North Lake City, UT
#
#   exterior_color interior_color
# 0         White           Gray
# 1          Gray          Black
# 2         Black           Gray
# 3         White          Black
# 4          Blue          Black

# %% [markdown]
# ### Step 12: Replace "Online" Retailer Locations with "Online" values in "location" Column

# %%
car_listings['location'] = car_listings['location'].str.replace('Online RetailerDelivery Available', 'Online')
car_listings.head(5)
# Out:
#                     vin   year       make     model model2 model3
# 0  VIN1FTBR1C83LKA62166   2020       Ford   Transit  Cargo    Van  \
# 1  VIN1GNSKDKD3NR208863   2022  Chevrolet  Suburban   None   None
# 2  VIN1G1FZ6S02N4108127   2022  Chevrolet      Bolt    EUV   None
# 3  VIN1FTEW1EB4MFA62542  2021        Ford     F-150   None   None
# 4  VIN1FTFW1E89MFA71147  2021        Ford     F-150   None   None
#
#                                    trim  price  mileage
# 0  T-250 148" Medium Roof 9070 GVWR RWD  41577    24465  \
# 1                               Z71 4WD  65998    27058
# 2                               Premier  33998     2370
# 3            XLT SuperCrew 5.5' Box 4WD  38499    15745
# 4            XLT SuperCrew 5.5' Box 4WD  35990    45732
#
#                            colors
# 0   White exterior, Gray interior  \
# 1   Gray exterior, Black interior
# 2   Black exterior, Gray interior
# 3  White exterior, Black interior
# 4   Blue exterior, Black interior
#
#                                       condition             location
# 0             1 accident, 1 Owner, Personal use       Lewisville, TX  \
# 1  No accidents reported, 1 Owner, Personal use          Tomball, TX
# 2  No accidents reported, 1 Owner, Personal use           Waukee, IA
# 3  No accidents reported, 1 Owner, Personal use        Blackfoot, ID
# 4             1 accident, 1 Owner, Personal use  North Lake City, UT
#
#   exterior_color interior_color
# 0         White           Gray
# 1          Gray          Black
# 2         Black           Gray
# 3         White          Black
# 4          Blue          Black

# %% [markdown]
# ### Step 13: Drop "colors" Column and Split "condition" Column into 3 New Columns

# %%
car_listings = car_listings.drop(columns=['colors'])

new_cols = car_listings['condition'].str.split(", ", n=3, expand=True)
car_listings['num_accidents'] = new_cols[0]
car_listings['num_owners'] = new_cols[1]
car_listings['use_type'] = new_cols[2]

car_listings.head(5)
# Out:
#                     vin   year       make     model model2 model3
# 0  VIN1FTBR1C83LKA62166   2020       Ford   Transit  Cargo    Van  \
# 1  VIN1GNSKDKD3NR208863   2022  Chevrolet  Suburban   None   None
# 2  VIN1G1FZ6S02N4108127   2022  Chevrolet      Bolt    EUV   None
# 3  VIN1FTEW1EB4MFA62542  2021        Ford     F-150   None   None
# 4  VIN1FTFW1E89MFA71147  2021        Ford     F-150   None   None
#
#                                    trim  price  mileage
# 0  T-250 148" Medium Roof 9070 GVWR RWD  41577    24465  \
# 1                               Z71 4WD  65998    27058
# 2                               Premier  33998     2370
# 3            XLT SuperCrew 5.5' Box 4WD  38499    15745
# 4            XLT SuperCrew 5.5' Box 4WD  35990    45732
#
#                                       condition             location
# 0             1 accident, 1 Owner, Personal use       Lewisville, TX  \
# 1  No accidents reported, 1 Owner, Personal use          Tomball, TX
# 2  No accidents reported, 1 Owner, Personal use           Waukee, IA
# 3  No accidents reported, 1 Owner, Personal use        Blackfoot, ID
# 4             1 accident, 1 Owner, Personal use  North Lake City, UT
#
#   exterior_color interior_color          num_accidents num_owners
# 0         White           Gray              1 accident    1 Owner  \
# 1          Gray          Black   No accidents reported    1 Owner
# 2         Black           Gray   No accidents reported    1 Owner
# 3         White          Black   No accidents reported    1 Owner
# 4          Blue          Black              1 accident    1 Owner
#
#        use_type
# 0  Personal use
# 1  Personal use
# 2  Personal use
# 3  Personal use
# 4  Personal use

# %% [markdown]
# ### Step 14: Drop "condition" Column and Clean "num_accidents", "num_owners", and "use_type" Columns

# %%
car_listings = car_listings.drop(columns=['condition'])

car_listings['num_accidents'] = np.where(car_listings['num_accidents'].str.contains('No'), '0', car_listings['num_accidents'].str[0:1])
car_listings['num_accidents'] = car_listings['num_accidents'].str.strip()
car_listings['num_owners'] = car_listings['num_owners'].str[0:1]
car_listings['num_owners'] = car_listings['num_owners'].str.strip()
car_listings['use_type'] = car_listings['use_type'].str.replace('use', '')

car_listings.head(5)
# Out:
#                     vin   year       make     model model2 model3
# 0  VIN1FTBR1C83LKA62166   2020       Ford   Transit  Cargo    Van  \
# 1  VIN1GNSKDKD3NR208863   2022  Chevrolet  Suburban   None   None
# 2  VIN1G1FZ6S02N4108127   2022  Chevrolet      Bolt    EUV   None
# 3  VIN1FTEW1EB4MFA62542  2021        Ford     F-150   None   None
# 4  VIN1FTFW1E89MFA71147  2021        Ford     F-150   None   None
#
#                                    trim  price  mileage             location
# 0  T-250 148" Medium Roof 9070 GVWR RWD  41577    24465       Lewisville, TX  \
# 1                               Z71 4WD  65998    27058          Tomball, TX
# 2                               Premier  33998     2370           Waukee, IA
# 3            XLT SuperCrew 5.5' Box 4WD  38499    15745        Blackfoot, ID
# 4            XLT SuperCrew 5.5' Box 4WD  35990    45732  North Lake City, UT
#
#   exterior_color interior_color num_accidents num_owners   use_type
# 0         White           Gray              1          1  Personal
# 1          Gray          Black              0          1  Personal
# 2         Black           Gray              0          1  Personal
# 3         White          Black              0          1  Personal
# 4          Blue          Black              1          1  Personal

# %% [markdown]
# ### Step 15: Convert "num_accidents" and "num_owners" to Int and "use_type" to Categorical

# %%
car_listings['num_accidents'] = car_listings['num_accidents'].astype(int)
car_listings['num_owners'] = car_listings['num_owners'].astype(int)
car_listings['use_type'] = car_listings['use_type'].astype('category')

car_listings.head(5)
# Out:
#                     vin   year       make     model model2 model3
# 0  VIN1FTBR1C83LKA62166   2020       Ford   Transit  Cargo    Van  \
# 1  VIN1GNSKDKD3NR208863   2022  Chevrolet  Suburban   None   None
# 2  VIN1G1FZ6S02N4108127   2022  Chevrolet      Bolt    EUV   None
# 3  VIN1FTEW1EB4MFA62542  2021        Ford     F-150   None   None
# 4  VIN1FTFW1E89MFA71147  2021        Ford     F-150   None   None
#
#                                    trim  price  mileage             location
# 0  T-250 148" Medium Roof 9070 GVWR RWD  41577    24465       Lewisville, TX  \
# 1                               Z71 4WD  65998    27058          Tomball, TX
# 2                               Premier  33998     2370           Waukee, IA
# 3            XLT SuperCrew 5.5' Box 4WD  38499    15745        Blackfoot, ID
# 4            XLT SuperCrew 5.5' Box 4WD  35990    45732  North Lake City, UT
#
#   exterior_color interior_color  num_accidents  num_owners   use_type
# 0         White           Gray               1           1  Personal
# 1          Gray          Black               0           1  Personal
# 2         Black           Gray               0           1  Personal
# 3         White          Black               0           1  Personal
# 4          Blue          Black               1           1  Personal

# %% [markdown]
# ### Step 16: Split "location" into 2 Columns

# %%
new_cols = car_listings['location'].str.split(", ", n=2, expand=True)
car_listings['city'] = new_cols[0]
car_listings['state'] = new_cols[1]

car_listings.head(5)
# Out:
#                     vin   year       make     model model2 model3
# 0  VIN1FTBR1C83LKA62166   2020       Ford   Transit  Cargo    Van  \
# 1  VIN1GNSKDKD3NR208863   2022  Chevrolet  Suburban   None   None
# 2  VIN1G1FZ6S02N4108127   2022  Chevrolet      Bolt    EUV   None
# 3  VIN1FTEW1EB4MFA62542  2021        Ford     F-150   None   None
# 4  VIN1FTFW1E89MFA71147  2021        Ford     F-150   None   None
#
#                                    trim  price  mileage             location
# 0  T-250 148" Medium Roof 9070 GVWR RWD  41577    24465       Lewisville, TX  \
# 1                               Z71 4WD  65998    27058          Tomball, TX
# 2                               Premier  33998     2370           Waukee, IA
# 3            XLT SuperCrew 5.5' Box 4WD  38499    15745        Blackfoot, ID
# 4            XLT SuperCrew 5.5' Box 4WD  35990    45732  North Lake City, UT
#
#   exterior_color interior_color  num_accidents  num_owners   use_type
# 0         White           Gray               1           1  Personal   \
# 1          Gray          Black               0           1  Personal
# 2         Black           Gray               0           1  Personal
# 3         White          Black               0           1  Personal
# 4          Blue          Black               1           1  Personal
#
#               city state
# 0       Lewisville    TX
# 1          Tomball    TX
# 2           Waukee    IA
# 3        Blackfoot    ID
# 4  North Lake City    UT

# %% [markdown]
# ### Step 17: Drop "location" column and Reorder Columns

# %%
car_listings = car_listings.drop(columns=['location'])

try:
    car_listings = car_listings[['vin', 'year', 'make', 'model', 'model2', 'model3', 'trim', 'price', 'mileage', 'city', 'state', 'exterior_color', 'interior_color', 'num_accidents', 'num_owners', 'use_type']]
except:
    car_listings = car_listings[['vin', 'year', 'make', 'model', 'model2', 'trim', 'price', 'mileage', 'city', 'state', 'exterior_color', 'interior_color', 'num_accidents', 'num_owners', 'use_type']]
car_listings.head(5)
# Out:
#                     vin   year       make     model model2 model3
# 0  VIN1FTBR1C83LKA62166   2020       Ford   Transit  Cargo    Van  \
# 1  VIN1GNSKDKD3NR208863   2022  Chevrolet  Suburban   None   None
# 2  VIN1G1FZ6S02N4108127   2022  Chevrolet      Bolt    EUV   None
# 3  VIN1FTEW1EB4MFA62542  2021        Ford     F-150   None   None
# 4  VIN1FTFW1E89MFA71147  2021        Ford     F-150   None   None
#
#                                    trim  price  mileage             city
# 0  T-250 148" Medium Roof 9070 GVWR RWD  41577    24465       Lewisville  \
# 1                               Z71 4WD  65998    27058          Tomball
# 2                               Premier  33998     2370           Waukee
# 3            XLT SuperCrew 5.5' Box 4WD  38499    15745        Blackfoot
# 4            XLT SuperCrew 5.5' Box 4WD  35990    45732  North Lake City
#
#   state exterior_color interior_color  num_accidents  num_owners   use_type
# 0    TX         White           Gray               1           1  Personal
# 1    TX          Gray          Black               0           1  Personal
# 2    IA         Black           Gray               0           1  Personal
# 3    ID         White          Black               0           1  Personal
# 4    UT          Blue          Black               1           1  Personal

# %% [markdown]
# ### Step 18: Extract Drivetrain Data into "drivetrain" Column

# %%
car_listings['drivetrain'] = np.where(car_listings['trim'].str.contains('FWD'), 'FWD', np.where(car_listings['trim'].str.contains('RWD') | car_listings['trim'].str.contains('2WD'), 'RWD', np.where(car_listings['trim'].str.contains('4WD'), '4WD', np.where(car_listings['trim'].str.contains('AWD'), 'AWD', 'Unknown'))))
car_listings.head(5)
# Out:
#                     vin   year       make     model model2 model3
# 0  VIN1FTBR1C83LKA62166   2020       Ford   Transit  Cargo    Van  \
# 1  VIN1GNSKDKD3NR208863   2022  Chevrolet  Suburban   None   None
# 2  VIN1G1FZ6S02N4108127   2022  Chevrolet      Bolt    EUV   None
# 3  VIN1FTEW1EB4MFA62542  2021        Ford     F-150   None   None
# 4  VIN1FTFW1E89MFA71147  2021        Ford     F-150   None   None
#
#                                    trim  price  mileage             city
# 0  T-250 148" Medium Roof 9070 GVWR RWD  41577    24465       Lewisville  \
# 1                               Z71 4WD  65998    27058          Tomball
# 2                               Premier  33998     2370           Waukee
# 3            XLT SuperCrew 5.5' Box 4WD  38499    15745        Blackfoot
# 4            XLT SuperCrew 5.5' Box 4WD  35990    45732  North Lake City
#
#   state exterior_color interior_color  num_accidents  num_owners   use_type
# 0    TX         White           Gray               1           1  Personal   \
# 1    TX          Gray          Black               0           1  Personal
# 2    IA         Black           Gray               0           1  Personal
# 3    ID         White          Black               0           1  Personal
# 4    UT          Blue          Black               1           1  Personal
#
#   drivetrain
# 0        RWD
# 1        4WD
# 2    Unknown
# 3        4WD
# 4        4WD

# %% [markdown]
# ### Step 19: Concatenate "model", "model2", and "model3" Columns

# %%
try:
    car_listings['model2'] = car_listings['model2'].fillna('')
    car_listings['model3'] = car_listings['model3'].fillna('')
    car_listings['model'] = np.where(car_listings['model3'] != None, car_listings['model'] + " " + car_listings['model2'] + " " + car_listings['model3'], np.where(car_listings['model2'] != None, car_listings['model'] + " " + car_listings['model2'], car_listings['model']))
except:
    car_listings['model2'] = car_listings['model2'].fillna('')
    car_listings['model'] = np.where(car_listings['model2'] != None, car_listings['model'] + " " + car_listings['model2'], car_listings['model'])
car_listings.head(5)
# Out:
#                     vin   year       make              model model2 model3
# 0  VIN1FTBR1C83LKA62166   2020       Ford  Transit Cargo Van  Cargo    Van  \
# 1  VIN1GNSKDKD3NR208863   2022  Chevrolet         Suburban
# 2  VIN1G1FZ6S02N4108127   2022  Chevrolet          Bolt EUV     EUV
# 3  VIN1FTEW1EB4MFA62542  2021        Ford            F-150
# 4  VIN1FTFW1E89MFA71147  2021        Ford            F-150
#
#                                    trim  price  mileage             city
# 0  T-250 148" Medium Roof 9070 GVWR RWD  41577    24465       Lewisville  \
# 1                               Z71 4WD  65998    27058          Tomball
# 2                               Premier  33998     2370           Waukee
# 3            XLT SuperCrew 5.5' Box 4WD  38499    15745        Blackfoot
# 4            XLT SuperCrew 5.5' Box 4WD  35990    45732  North Lake City
#
#   state exterior_color interior_color  num_accidents  num_owners   use_type
# 0    TX         White           Gray               1           1  Personal   \
# 1    TX          Gray          Black               0           1  Personal
# 2    IA         Black           Gray               0           1  Personal
# 3    ID         White          Black               0           1  Personal
# 4    UT          Blue          Black               1           1  Personal
#
#   drivetrain
# 0        RWD
# 1        4WD
# 2    Unknown
# 3        4WD
# 4        4WD

# %% [markdown]
# ### Step 20: Remove "model2" and "model3" Columns and Extract Transmission Data into "transmission" Column

# %%
car_listings = car_listings.drop(columns=['model2', 'model3'])

car_listings['transmission'] = np.where(car_listings['trim'].str.contains('CVT'), 'CVT', np.where(car_listings['trim'].str.contains('Automatic'), 'Automatic', 'Unknown'))

car_listings.head(5)
# Out:
#                     vin   year       make              model
# 0  VIN1FTBR1C83LKA62166   2020       Ford  Transit Cargo Van  \
# 1  VIN1GNSKDKD3NR208863   2022  Chevrolet         Suburban
# 2  VIN1G1FZ6S02N4108127   2022  Chevrolet          Bolt EUV
# 3  VIN1FTEW1EB4MFA62542  2021        Ford            F-150
# 4  VIN1FTFW1E89MFA71147  2021        Ford            F-150
#
#                                    trim  price  mileage             city
# 0  T-250 148" Medium Roof 9070 GVWR RWD  41577    24465       Lewisville  \
# 1                               Z71 4WD  65998    27058          Tomball
# 2                               Premier  33998     2370           Waukee
# 3            XLT SuperCrew 5.5' Box 4WD  38499    15745        Blackfoot
# 4            XLT SuperCrew 5.5' Box 4WD  35990    45732  North Lake City
#
#   state exterior_color interior_color  num_accidents  num_owners   use_type
# 0    TX         White           Gray               1           1  Personal   \
# 1    TX          Gray          Black               0           1  Personal
# 2    IA         Black           Gray               0           1  Personal
# 3    ID         White          Black               0           1  Personal
# 4    UT          Blue          Black               1           1  Personal
#
#   drivetrain transmission
# 0        RWD      Unknown
# 1        4WD      Unknown
# 2    Unknown      Unknown
# 3        4WD      Unknown
# 4        4WD      Unknown

# %% [markdown]
# ### Step 21: Remove Drivetrain and Transmission Data from "trim" Column and Reorder Columns

# %%
car_listings['trim'] = car_listings['trim'].str.replace('4WD', '')
car_listings['trim'] = car_listings['trim'].str.replace('AWD', '')
car_listings['trim'] = car_listings['trim'].str.replace('FWD', '')
car_listings['trim'] = car_listings['trim'].str.replace('RWD', '')
car_listings['trim'] = car_listings['trim'].str.replace('2WD', '')
car_listings['trim'] = car_listings['trim'].str.replace('CVT', '')
car_listings['trim'] = car_listings['trim'].str.replace('Automatic', '')

car_listings = car_listings[['vin', 'year', 'make', 'model', 'trim', 'price', 'mileage', 'drivetrain', 'transmission', 'city', 'state', 'exterior_color', 'interior_color', 'num_accidents', 'num_owners', 'use_type']]
car_listings.head(10)
# Out:
#                     vin   year       make              model
# 0  VIN1FTBR1C83LKA62166   2020       Ford  Transit Cargo Van  \
# 1  VIN1GNSKDKD3NR208863   2022  Chevrolet         Suburban
# 2  VIN1G1FZ6S02N4108127   2022  Chevrolet          Bolt EUV
# 3  VIN1FTEW1EB4MFA62542  2021        Ford            F-150
# 4  VIN1FTFW1E89MFA71147  2021        Ford            F-150
# 5  VIN1FTEW1EG4JFD01384  2018        Ford            F-150
# 6  VIN1C6SRFJT0KN560009  2019         Ram             1500
# 7  VIN1FTEW1E4XKFA85239  2019        Ford            F-150
# 8  VIN1FTEW1CP1KKC31807  2019        Ford            F-150
# 9  VIN1FT7W2BT4HEB30006  2017        Ford   Super Duty F-250
#
#                                 trim  price  mileage drivetrain transmission
# 0  T-250 148" Medium Roof 9070 GVWR   41577    24465        RWD      Unknown  \
# 1                               Z71   65998    27058        4WD      Unknown
# 2                            Premier  33998     2370    Unknown      Unknown
# 3            XLT SuperCrew 5.5' Box   38499    15745        4WD      Unknown
# 4            XLT SuperCrew 5.5' Box   35990    45732        4WD      Unknown
# 5            XLT SuperCrew 5.5' Box   17990   201264        4WD      Unknown
# 6         Laramie Crew Cab 5'7" Box   23998   163677        4WD      Unknown
# 7            XLT SuperCrew 5.5' Box   32500    34572        4WD      Unknown
# 8             XL SuperCrew 5.5' Box   19499   163256        RWD      Unknown
# 9            Lariat Crew Cab 8' Bed   29995   200922        4WD      Unknown
#
#               city state exterior_color interior_color  num_accidents
# 0       Lewisville    TX         White           Gray               1  \
# 1          Tomball    TX          Gray          Black               0
# 2           Waukee    IA         Black           Gray               0
# 3        Blackfoot    ID         White          Black               0
# 4  North Lake City    UT          Blue          Black               1
# 5       Wilmington    NC        Silver           Gray               0
# 6      Panama City    FL          Gray          Black               0
# 7       Post Falls    ID           Red           Gray               0
# 8       Lewisville    TX         Black          Black               0
# 9        Lumberton    TX         White        Unknown               0
#
#    num_owners   use_type
# 0           1  Personal
# 1           1  Personal
# 2           1  Personal
# 3           1  Personal
# 4           1  Personal
# 5           1  Personal
# 6           1  Personal
# 7           1  Personal
# 8           1  Personal
# 9           1  Personal

# %% [markdown]
# ### Step 22: Preview Column Data Types

# %%
car_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   vin             33 non-null     object
#  1   year            33 non-null     object
#  2   make            33 non-null     object
#  3   model           33 non-null     object
#  4   trim            33 non-null     object
#  5   price           33 non-null     int32
#  6   mileage         33 non-null     int32
#  7   drivetrain      33 non-null     object
#  8   transmission    33 non-null     object
#  9   city            33 non-null     object
#  10  state           33 non-null     object
#  11  exterior_color  33 non-null     object
#  12  interior_color  33 non-null     object
#  13  num_accidents   33 non-null     int32
#  14  num_owners      33 non-null     int32
#  15  use_type        33 non-null     category
# dtypes: category(1), int32(4), object(11)
# memory usage: 3.6+ KB

# %% [markdown]
# ### Step 23: Set Official Data Types

# %%
car_listings['year'] = car_listings['year'].str.strip()
car_listings['year'] = car_listings['year'].astype(int)

car_listings['drivetrain'] = car_listings['drivetrain'].astype('category')

car_listings['transmission'] = car_listings['transmission'].astype('category')

car_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   vin             33 non-null     object
#  1   year            33 non-null     int32
#  2   make            33 non-null     object
#  3   model           33 non-null     object
#  4   trim            33 non-null     object
#  5   price           33 non-null     int32
#  6   mileage         33 non-null     int32
#  7   drivetrain      33 non-null     category
#  8   transmission    33 non-null     category
#  9   city            33 non-null     object
#  10  state           33 non-null     object
#  11  exterior_color  33 non-null     object
#  12  interior_color  33 non-null     object
#  13  num_accidents   33 non-null     int32
#  14  num_owners      33 non-null     int32
#  15  use_type        33 non-null     category
# dtypes: category(3), int32(5), object(8)
# memory usage: 3.4+ KB

# %% [markdown]
# ### Step 24: Output Final Batch

# %%
car_listings
# Out:
#                      vin  year       make              model
# 0   VIN1FTBR1C83LKA62166  2020       Ford  Transit Cargo Van  \
# 1   VIN1GNSKDKD3NR208863  2022  Chevrolet         Suburban
# 2   VIN1G1FZ6S02N4108127  2022  Chevrolet          Bolt EUV
# 3   VIN1FTEW1EB4MFA62542  2021       Ford            F-150
# 4   VIN1FTFW1E89MFA71147  2021       Ford            F-150
# 5   VIN1FTEW1EG4JFD01384  2018       Ford            F-150
# 6   VIN1C6SRFJT0KN560009  2019        Ram             1500
# 7   VIN1FTEW1E4XKFA85239  2019       Ford            F-150
# 8   VIN1FTEW1CP1KKC31807  2019       Ford            F-150
# 9   VIN1FT7W2BT4HEB30006  2017       Ford   Super Duty F-250
# 10  VIN1FTEW1EP0LKD99145  2020       Ford            F-150
# 11  VIN1FTEW1EP5LKF18954  2020       Ford            F-150
# 12  VIN1FTEW1E47KFC13551  2019       Ford            F-150
# 13  VIN1FTEW1E50JKC63092  2018       Ford            F-150
# 14  VIN5YFEPMAE4NP281736  2022     Toyota          Corolla
# 15  VINJTDKN3DU2A0027744  2010     Toyota            Prius
# 16  VIN5N1AT2MV3LC792575  2020     Nissan            Rogue
# 17  VIN1FATP8UH6M5131407  2021       Ford          Mustang
# 18  VIN1FTEX1EB4LFA73343  2020       Ford            F-150
# 19  VIN1FTEW1E5XKKD22361  2019       Ford            F-150
# 20  VIN1FTEX1CPXGKF06532  2016       Ford            F-150
# 21  VIN1FT7X2B62KEE32988  2019       Ford   Super Duty F-250
# 22  VINKNMAT2MV6LP533964  2020     Nissan            Rogue
# 23  VIN1FTEW1EG1GFB45846  2016       Ford            F-150
# 24  VIN1GCWGAFPXK1365914  2019  Chevrolet  Express Cargo Van
# 25  VIN1FTEW1EB5KFC57627  2019       Ford            F-150
# 26  VIN1FTFW1E85MKE08565  2021       Ford            F-150
# 27  VIN1FTEW1EB8KFB38129  2019       Ford            F-150
# 28  VIN5YFEPRAE2LP133823  2020     Toyota          Corolla
# 29  VIN1FTEW1E57JFB14476  2018       Ford            F-150
# 30  VIN1N4AL3APXGN382310  2016     Nissan           Altima
# 31  VIN1FTFW1EF2EKG17178  2014       Ford            F-150
# 32  VIN3FA6P0HD2LR172330  2020       Ford           Fusion
#
#                                  trim  price  mileage drivetrain transmission
# 0   T-250 148" Medium Roof 9070 GVWR   41577    24465        RWD      Unknown  \
# 1                                Z71   65998    27058        4WD      Unknown
# 2                             Premier  33998     2370    Unknown      Unknown
# 3             XLT SuperCrew 5.5' Box   38499    15745        4WD      Unknown
# 4             XLT SuperCrew 5.5' Box   35990    45732        4WD      Unknown
# 5             XLT SuperCrew 5.5' Box   17990   201264        4WD      Unknown
# 6          Laramie Crew Cab 5'7" Box   23998   163677        4WD      Unknown
# 7             XLT SuperCrew 5.5' Box   32500    34572        4WD      Unknown
# 8              XL SuperCrew 5.5' Box   19499   163256        RWD      Unknown
# 9             Lariat Crew Cab 8' Bed   29995   200922        4WD      Unknown
# 10            XLT SuperCrew 5.5' Box   33999    39241        4WD      Unknown
# 11             XL SuperCrew 5.5' Box   27699    76799        4WD      Unknown
# 12            XLT SuperCrew 5.5' Box   29994    32378        4WD      Unknown
# 13            XLT SuperCrew 5.5' Box   17495   225850        4WD      Unknown
# 14                                LE   18990    22902    Unknown          CVT
# 15                                Two   9991   130678    Unknown      Unknown
# 16                                SV   12995   190604        AWD      Unknown
# 17       EcoBoost Premium Convertible  26499    31097    Unknown      Unknown
# 18              XL SuperCab 6.5' Box   22889   130500        4WD      Unknown
# 19            XLT SuperCrew 5.5' Box   24000   138677        4WD      Unknown
# 20              XL SuperCab 6.5' Box   17988    81054        RWD      Unknown
# 21                XL  SuperCab 8' Box  22800   189991        4WD      Unknown
# 22                                SV   17496    52713        AWD      Unknown
# 23            XLT SuperCrew 5.5' Box   17998   142782        4WD      Unknown
# 24                           2500 SWB  15995   267492    Unknown      Unknown
# 25            XLT SuperCrew 5.5' Box   24517   114036        4WD      Unknown
# 26            XLT SuperCrew 5.5' Box   41971    25236        4WD      Unknown
# 27            XLT SuperCrew 5.5' Box   27064    80095        4WD      Unknown
# 28                                LE   19995    25688    Unknown          CVT
# 29            XLT SuperCrew 5.5' Box   25850    85344        4WD      Unknown
# 30                              2.5 S  10999    82371    Unknown      Unknown
# 31            STX SuperCrew 5.5' Box   12900   237511        4WD      Unknown
# 32                                SE   14500    73059        FWD      Unknown
#
#                city state exterior_color interior_color  num_accidents
# 0        Lewisville    TX         White           Gray               1  \
# 1           Tomball    TX          Gray          Black               0
# 2            Waukee    IA         Black           Gray               0
# 3         Blackfoot    ID         White          Black               0
# 4   North Lake City    UT          Blue          Black               1
# 5        Wilmington    NC        Silver           Gray               0
# 6       Panama City    FL          Gray          Black               0
# 7        Post Falls    ID           Red           Gray               0
# 8        Lewisville    TX         Black          Black               0
# 9         Lumberton    TX         White        Unknown               0
# 10           Burley    ID         White           Gray               0
# 11        Littleton    CO         White           Gray               0
# 12          Seffner    FL          Gray           Gray               1
# 13       Scottsdale    AZ         White           Gray               0
# 14  Fort Lauderdale    FL         White          Black               0
# 15       Sacramento    CA         White        Unknown               0
# 16          Everett    WA         White          Black               0
# 17       Fort Myers    FL         White          Black               1
# 18       Chesapeake    VA         White           Gray               0
# 19      Albuquerque    NM         White           Gray               0
# 20       Sacramento    CA         Black           Gray               0
# 21           Deland    FL         White           Gray               0
# 22      Saint James    NY        Silver          Black               0
# 23        Lexington    KY         White           Gray               1
# 24        Arlington    TX         White           Gray               0
# 25       Fort Wayne    IN         Black           Gray               0
# 26       Marysville    WA         White          Black               0
# 27       Fort Wayne    IN           Red        Unknown               0
# 28       Sacramento    CA         White           Gray               0
# 29       Fort Wayne    IN         Black        Unknown               1
# 30        San Diego    CA        Silver          Black               1
# 31            Miami    FL         White          Black               0
# 32    Riviera Beach    FL         Black          Black               0
#
#     num_owners   use_type
# 0            1  Personal
# 1            1  Personal
# 2            1  Personal
# 3            1  Personal
# 4            1  Personal
# 5            1  Personal
# 6            1  Personal
# 7            1  Personal
# 8            1  Personal
# 9            1  Personal
# 10           1  Personal
# 11           1  Personal
# 12           1  Personal
# 13           2     Fleet
# 14           2  Personal
# 15           3  Personal
# 16           1     Fleet
# 17           1  Personal
# 18           1  Personal
# 19           1  Personal
# 20           2     Fleet
# 21           1  Personal
# 22           1  Personal
# 23           2  Personal
# 24           1     Fleet
# 25           1  Personal
# 26           1  Personal
# 27           1     Fleet
# 28           2  Personal
# 29           1  Personal
# 30           3  Personal
# 31           1  Personal
# 32           2     Fleet

# %%
output = pd.read_csv('car_listings.csv')
outer = car_listings.merge(output, how='outer', indicator=True)
anti_join = outer[(outer._merge=='left_only')].drop('_merge', axis=1)
pd.DataFrame(anti_join)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Chase\OneDrive\Documents\Career Development\Summer 2023 Project\Web-Scraping-Final.ipynb Cell 52 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Chase/OneDrive/Documents/Career%20Development/Summer%202023%20Project/Web-Scraping-Final.ipynb#Y102sZmlsZQ%3D%3D?line=0'>1</a> output = pd.read_csv('car_listings.csv')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Chase/OneDrive/Documents/Career%20Development/Summer%202023%20Project/Web-Scraping-Final.ipynb#Y102sZmlsZQ%3D%3D?line=1'>2</a> outer = car_listings.merge(output, how='outer', indicator=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/Chase/OneDrive/Documents/Career%20Development/Summer%202023%20Project/Web-Scraping-Final.ipynb#Y102sZmlsZQ%3D%3D?line=2'>3</a> anti_join = outer[(outer._merge=='left_only')].drop('_merge', axis=1)
#       <a href='vscode-notebook-cell:/c%3A/Users/Chase/OneDrive/Documents/Career%20Development/Summer%202023%20Project/Web-Scraping-Final.ipynb#Y102sZmlsZQ%3D%3D?line=3'>4</a> pd.DataFrame(anti_join)
#
# File c:\Users\Chase\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:9822, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9803 @Substitution("")
#    9804 @Appender(_merge_doc, indents=2)
#    9805 def merge(
#    (...)
#    9818     validate: str | None = None,
#    9819 ) -> DataFrame:
#    9820     from pandas.core.reshape.merge import merge
# -> 9822     return merge(
#    9823         self,
#    9824         right,
#    9825         how=how,
#    9826         on=on,
#    9827         left_on=left_on,
#    9828         right_on=right_on,
#    9829         left_index=left_index,
#    9830         right_index=right_index,
#    9831         sort=sort,
#    9832         suffixes=suffixes,
#    9833         copy=copy,
#    9834         indicator=indicator,
#    9835         validate=validate,
#    9836     )
#
# File c:\Users\Chase\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\reshape\merge.py:142, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     125 @Substitution("\nleft : DataFrame or named Series")
#     126 @Appender(_merge_doc, indents=0)
#     127 def merge(
#    (...)
#     140     validate: str | None = None,
#     141 ) -> DataFrame:
# --> 142     op = _MergeOperation(
#     143         left,
#     144         right,
#     145         how=how,
#     146         on=on,
#     147         left_on=left_on,
#     148         right_on=right_on,
#     149         left_index=left_index,
#     150         right_index=right_index,
#     151         sort=sort,
#     152         suffixes=suffixes,
#     153         indicator=indicator,
#     154         validate=validate,
#     155     )
#     156     return op.get_result(copy=copy)
#
# File c:\Users\Chase\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\reshape\merge.py:735, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     727 (
#     728     self.left_join_keys,
#     729     self.right_join_keys,
#     730     self.join_names,
#     731 ) = self._get_merge_keys()
#     733 # validate the merge keys dtypes. We may need to coerce
#     734 # to avoid incompatible dtypes
# --> 735 self._maybe_coerce_merge_keys()
#     737 # If argument passed to validate,
#     738 # check if columns specified as unique
#     739 # are in fact unique.
#     740 if validate is not None:
#
# File c:\Users\Chase\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\reshape\merge.py:1387, in _MergeOperation._maybe_coerce_merge_keys(self)
#    1381     # unless we are merging non-string-like with string-like
#    1382     elif (
#    1383         inferred_left in string_types and inferred_right not in string_types
#    1384     ) or (
#    1385         inferred_right in string_types and inferred_left not in string_types
#    1386     ):
# -> 1387         raise ValueError(msg)
#    1389 # datetimelikes must match exactly
#    1390 elif needs_i8_conversion(lk.dtype) and not needs_i8_conversion(rk.dtype):
#
# ValueError: You are trying to merge on int32 and object columns. If you wish to proceed you should use pd.concat

# %% [markdown]
# ## Output to Parquet File

# %%
#car_listings.to_csv('car_listings.csv', index=False, mode='a', header=False)

# %%
# all_listings = pd.read_csv('car_listings.csv')
# len(all_listings)
# Out:
# 15965
